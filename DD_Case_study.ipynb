# %% [markdown]
# ## Exploratory Data Analysis

# %%
#Call the necessary libraries for data exploration and preprocessing
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# read your data and store it into a dataframe
df = pd.read_csv("/content/drive/MyDrive/BUAN601/DeansDilemmaData.csv")

# %%
display(df.head())
# Out:
#    SlNo  Gender-B  Percent_SSC  Board_CBSE  Board_ICSE  Percent_HSC  \
# 0     1         0        62.00           0           0        88.00
# 1     2         0        76.33           0           1        75.33
# 2     3         0        72.00           0           0        78.00
# 3     4         0        60.00           1           0        63.00
# 4     5         0        61.00           1           0        55.00
#
#    Percent_Degree  Degree_Engg  Experience_Yrs  S-TEST  Percentile_ET  \
# 0           52.00            0               0       1           55.0
# 1           75.48            0               1       1           86.5
# 2           66.63            1               0       0            0.0
# 3           58.00            0               0       1           75.0
# 4           54.00            1               1       1           66.0
#
#    S-TEST*SCORE  Percent_MBA  Marks_Communication  Marks_Projectwork  \
# ...

# %%
# Check type of features inside the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 391 entries, 0 to 390
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   SlNo                 391 non-null    int64
#  1   Gender-B             391 non-null    int64
#  2   Percent_SSC          391 non-null    float64
#  3   Board_CBSE           391 non-null    int64
#  4   Board_ICSE           391 non-null    int64
#  5   Percent_HSC          391 non-null    float64
#  6   Percent_Degree       391 non-null    float64
#  7   Degree_Engg          391 non-null    int64
#  8   Experience_Yrs       391 non-null    int64
#  9   S-TEST               391 non-null    int64
#  10  Percentile_ET        391 non-null    float64
#  11  S-TEST*SCORE         391 non-null    float64
#  12  Percent_MBA          391 non-null    float64
#  13  Marks_Communication  391 non-null    int64
#  14  Marks_Projectwork    391 non-null    int64
# ...

# %%
# Show the descriptive statistics of the raw data
df.describe()
# Out:
#              SlNo    Gender-B  Percent_SSC  Board_CBSE  Board_ICSE  \
# count  391.000000  391.000000   391.000000  391.000000  391.000000
# mean   196.000000    0.324808    64.652353    0.289003    0.196931
# std    113.016223    0.468903    10.960426    0.453880    0.398189
# min      1.000000    0.000000    37.000000    0.000000    0.000000
# 25%     98.500000    0.000000    56.000000    0.000000    0.000000
# 50%    196.000000    0.000000    64.500000    0.000000    0.000000
# 75%    293.500000    1.000000    74.000000    1.000000    0.000000
# max    391.000000    1.000000    87.200000    1.000000    1.000000
#
#        Percent_HSC  Percent_Degree  Degree_Engg  Experience_Yrs      S-TEST  \
# count   391.000000      391.000000   391.000000      391.000000  391.000000
# mean     63.795294       62.983606     0.094629        0.478261    0.828645
# std      11.417726        8.916152     0.293077        0.667112    0.377302
# ...

# %%
#warnings.filterwarnings("ignore")
for i in df. select_dtypes(include="number").columns:
    sns.histplot(data=df, x=i)
    plt.show()

# %%
#Show the neumeric features
df.select_dtypes(include="number").columns
# Out:
# Index(['SlNo', 'Gender-B', 'Percent_SSC', 'Board_CBSE', 'Board_ICSE',
#        'Percent_HSC', 'Percent_Degree', 'Degree_Engg', 'Experience_Yrs',
#        'S-TEST', 'Percentile_ET', 'S-TEST*SCORE', 'Percent_MBA',
#        'Marks_Communication', 'Marks_Projectwork', 'Marks_BOCA',
#        'Placement_B'],
#       dtype='object')

# %%
# Show the scatter plot for these neumeric features
#Scatter plot
for i in ['Gender-B', 'Percent_SSC', 'Board_CBSE', 'Board_ICSE',
       'Percent_HSC', 'Percent_Degree', 'Degree_Engg', 'Experience_Yrs',
       'S-TEST', 'Percentile_ET', 'S-TEST*SCORE', 'Percent_MBA',
       'Marks_Communication', 'Marks_Projectwork', 'Marks_BOCA']:
    sns.scatterplot(data=df,x=i, y='Placement_B')
    plt.show()

# %%
# drop the duplicate information inside the data
df.drop_duplicates()
# Out:
#      SlNo  Gender-B  Percent_SSC  Board_CBSE  Board_ICSE  Percent_HSC  \
# 0       1         0        62.00           0           0        88.00
# 1       2         0        76.33           0           1        75.33
# 2       3         0        72.00           0           0        78.00
# 3       4         0        60.00           1           0        63.00
# 4       5         0        61.00           1           0        55.00
# ..    ...       ...          ...         ...         ...          ...
# 386   387         0        62.60           0           0        50.60
# 387   388         0        77.00           0           0        49.50
# 388   389         0        66.40           0           0        72.00
# 389   390         1        70.00           0           1        77.00
# 390   391         0        74.00           0           0        85.00
#
#      Percent_Degree  Degree_Engg  Experience_Yrs  S-TEST  Percentile_ET  \
# ...

# %% [markdown]
# **Logistic Regression for predicting the placement**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
display(df.head())
# Out:
#    SlNo  Gender-B  Percent_SSC  Board_CBSE  Board_ICSE  Percent_HSC  \
# 0     1         0        62.00           0           0        88.00
# 1     2         0        76.33           0           1        75.33
# 2     3         0        72.00           0           0        78.00
# 3     4         0        60.00           1           0        63.00
# 4     5         0        61.00           1           0        55.00
#
#    Percent_Degree  Degree_Engg  Experience_Yrs  S-TEST  Percentile_ET  \
# 0           52.00            0               0       1           55.0
# 1           75.48            0               1       1           86.5
# 2           66.63            1               0       0            0.0
# 3           58.00            0               0       1           75.0
# 4           54.00            1               1       1           66.0
#
#    S-TEST*SCORE  Percent_MBA  Marks_Communication  Marks_Projectwork  \
# ...

# %%
# ----------------- Step 1: Classification (Placement Prediction) -----------------
# Selecting features for classification
features = ['Gender-B','Percent_SSC','Board_CBSE','Board_ICSE','Percent_HSC', 'Percent_Degree', 'Degree_Engg', 'Experience_Yrs','S-TEST', 'Percentile_ET', 'S-TEST*SCORE']
X_class = df[features]
y_class = df['Placement_B']  # 1 = Placed, 0 = Not Placed

# %%
# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X_class, y_class, test_size=0.3, random_state=42)

# %%
# Standardization
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
# Logistic Regression Model
log_reg = LogisticRegression()
log_reg.fit(X_train_scaled, y_train)
# Out:
# LogisticRegression()

# %%
# Predictions and evaluation
y_pred = log_reg.predict(X_test_scaled)
accuracy = accuracy_score(y_test, y_pred)
print(f"Classification Accuracy: {accuracy:.4f}")
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))
# Out:
# Classification Accuracy: 0.8136
# Confusion Matrix:
# [[ 0 22]
#  [ 0 96]]

# %%
from sklearn.metrics import classification_report

# Print classification report
print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        22
#            1       0.81      1.00      0.90        96
#
#     accuracy                           0.81       118
#    macro avg       0.41      0.50      0.45       118
# weighted avg       0.66      0.81      0.73       118
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %%
# Display the coefficients and intercept of the logistic regression model
coefficients = log_reg.coef_[0]
intercept = log_reg.intercept_[0]
feature_names = X_class.columns

print("\nLogistic Regression Coefficients:")
for feature, coef in zip(feature_names, coefficients):
    print(f"{feature}: {coef:.4f}")

print(f"\nIntercept: {intercept:.4f}")
# Out:
# Logistic Regression Coefficients:
# Gender-B: -0.1978
# Percent_SSC: 0.4550
# Board_CBSE: 0.2578
# Board_ICSE: -0.0983
# Percent_HSC: -0.0395
# Percent_Degree: -0.0518
# Degree_Engg: -0.1701
# Experience_Yrs: 0.2421
# S-TEST: -0.1690
# Percentile_ET: 0.1545
# S-TEST*SCORE: 0.1545
#
# Intercept: 1.4430

# %% [markdown]
# # Fearture selection
# ![image.png](data:image/png;base64,...)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.feature_selection import SelectFromModel
tree_gini = DecisionTreeClassifier(criterion="gini", random_state=42, max_depth=5)
tree_gini.fit(X_train, y_train)

# Select features with importance > mean
selector_gini = SelectFromModel(tree_gini, prefit=True, threshold="mean")
X_train_gini = selector_gini.transform(X_train)
X_test_gini = selector_gini.transform(X_test)

print("\n[Gini] Selected features:")
print(feature_names[selector_gini.get_support()])
# Out:
# [Gini] Selected features:
# Index(['Percent_SSC', 'Board_CBSE', 'Percent_HSC', 'Percent_Degree',
#        'S-TEST*SCORE'],
#       dtype='object')
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(

# %%
# ----------------- Step 1: Classification (Placement Prediction) -----------------
# Selecting features for classification
features = ['Percent_SSC', 'Percent_HSC', 'Percent_Degree', 'S-TEST*SCORE']
X_class = df[features]
y_class = df['Placement_B']  # 1 = Placed, 0 = Not Placed

# %%
# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X_class, y_class, test_size=0.2, random_state=42)

# %%
# Standardization
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
# Logistic Regression Model
log_reg = LogisticRegression()
log_reg.fit(X_train_scaled, y_train)
# Out:
# LogisticRegression()

# %%
# Predictions and evaluation
y_pred = log_reg.predict(X_test_scaled)
accuracy = accuracy_score(y_test, y_pred)
print(f"Classification Accuracy: {accuracy:.4f}")
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))
# Out:
# Classification Accuracy: 0.8354
# Confusion Matrix:
# [[ 0 13]
#  [ 0 66]]

# %%
from sklearn.metrics import classification_report

# Print classification report
print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        13
#            1       0.84      1.00      0.91        66
#
#     accuracy                           0.84        79
#    macro avg       0.42      0.50      0.46        79
# weighted avg       0.70      0.84      0.76        79
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %%
# Example of Feature Engineering: Creating a combined score
df['Academic_Score'] = df['Percent_SSC'] + df['Percent_HSC'] + df['Percent_Degree']
display(df[['Percent_SSC', 'Percent_HSC', 'Percent_Degree', 'Academic_Score']].head())
# Out:
#    Percent_SSC  Percent_HSC  Percent_Degree  Academic_Score
# 0        62.00        88.00           52.00          202.00
# 1        76.33        75.33           75.48          227.14
# 2        72.00        78.00           66.63          216.63
# 3        60.00        63.00           58.00          181.00
# 4        61.00        55.00           54.00          170.00

# %%
# read your data and store it into a dataframe
df = pd.read_csv("/content/drive/MyDrive/BUAN601/DeansDilemmaData.csv")

# %%
display(df.head())
# Out:
#    SlNo  Gender-B  Percent_SSC  Board_CBSE  Board_ICSE  Percent_HSC  \
# 0     1         0        62.00           0           0        88.00
# 1     2         0        76.33           0           1        75.33
# 2     3         0        72.00           0           0        78.00
# 3     4         0        60.00           1           0        63.00
# 4     5         0        61.00           1           0        55.00
#
#    Percent_Degree  Degree_Engg  Experience_Yrs  S-TEST  Percentile_ET  \
# 0           52.00            0               0       1           55.0
# 1           75.48            0               1       1           86.5
# 2           66.63            1               0       0            0.0
# 3           58.00            0               0       1           75.0
# 4           54.00            1               1       1           66.0
#
#    S-TEST*SCORE  Percent_MBA  Marks_Communication  Marks_Projectwork  \
# ...

# %%
# Example of Feature Engineering: Creating a combined score
df['Academic_Score'] = df['Percent_SSC'] + df['Percent_HSC'] + df['Percent_Degree']
display(df[['Percent_SSC', 'Percent_HSC', 'Percent_Degree', 'Academic_Score']].head())
# Out:
#    Percent_SSC  Percent_HSC  Percent_Degree  Academic_Score
# 0        62.00        88.00           52.00          202.00
# 1        76.33        75.33           75.48          227.14
# 2        72.00        78.00           66.63          216.63
# 3        60.00        63.00           58.00          181.00
# 4        61.00        55.00           54.00          170.00

# %%
# ----------------- Step 1: Classification (Placement Prediction) with Academic_Score -----------------
# Selecting features for classification including the new feature
features_with_academic = ['Gender-B','Board_CBSE','Board_ICSE', 'Degree_Engg', 'Experience_Yrs','S-TEST', 'Percentile_ET', 'S-TEST*SCORE', 'Academic_Score']
X_class_new = df[features_with_academic]
y_class_new = df['Placement_B']  # 1 = Placed, 0 = Not Placed

# %%
# Train-test split
X_train_new, X_test_new, y_train_new, y_test_new = train_test_split(X_class_new, y_class_new, test_size=0.2, random_state=42)

# %%
# Standardization
scaler_new = StandardScaler()
X_train_scaled_new = scaler_new.fit_transform(X_train_new)
X_test_scaled_new = scaler_new.transform(X_test_new)

# %%
# Logistic Regression Model
log_reg_new = LogisticRegression()
log_reg_new.fit(X_train_scaled_new, y_train_new)
# Out:
# LogisticRegression()

# %%
# Predictions and evaluation
y_pred_new = log_reg_new.predict(X_test_scaled_new)
accuracy_new = accuracy_score(y_test_new, y_pred_new)
print(f"Classification Accuracy with Academic_Score: {accuracy_new:.4f}")
print("Confusion Matrix with Academic_Score:")
print(confusion_matrix(y_test_new, y_pred_new))
# Out:
# Classification Accuracy with Academic_Score: 0.8354
# Confusion Matrix with Academic_Score:
# [[ 0 13]
#  [ 0 66]]

# %%
from sklearn.metrics import classification_report

# Print classification report
print("\nClassification Report with Academic_Score:")
print(classification_report(y_test_new, y_pred_new))
# Out:
# Classification Report with Academic_Score:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        13
#            1       0.84      1.00      0.91        66
#
#     accuracy                           0.84        79
#    macro avg       0.42      0.50      0.46        79
# weighted avg       0.70      0.84      0.76        79
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...
